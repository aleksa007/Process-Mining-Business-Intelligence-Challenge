# %% [markdown]
# # Decision Trees for predicting the next event of a case

# %%
import os
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error, accuracy_score
from progressbar import ProgressBar
import numpy as np
import time

# %%
start_time = time.time()

# %%
os.chdir("../")

# %%
data_train = pd.read_csv('data/road-train-pre.csv', error_bad_lines=False)
data_test = pd.read_csv('data/road-test-pre.csv', error_bad_lines=False)

# %%
data_train['event time:timestamp'] = pd.to_datetime(data_train['event time:timestamp'])
data_train = data_train.sort_values(by=['case concept:name', 'event time:timestamp'])

# %%
data_test['event time:timestamp'] = pd.to_datetime(data_test['event time:timestamp'])
data_test = data_test.sort_values(by=['case concept:name', 'event time:timestamp'])

# %% [markdown]
# # 1. Train Data

# %%
data_train.to_csv("fixed.csv")

file = open('fixed.csv', 'r')
log = dict()
with open('fixed.csv', 'r') as file:
    next(file)
    for line in file:
        line = line.strip()
        if len(line) == 0:
            continue
        parts = line.split(',')
        caseid = parts[2]

        task = parts[3]
        timestamp = parts[5]

        if caseid not in log:
            log[caseid] = [[],[]]

        log[caseid][0].append(task)
        log[caseid][1].append(timestamp)
        
file.close()

os.remove('fixed.csv')

# %%
for i in log.keys():
    current = log[i][0]  # recording the current case' events
    
    real_next = current[1:]  # next real event
    real_next.append('New Case')  # adding a 'new case' as real next event for every last event
    
    log[i].append(real_next)  # adding the real next events to the log file

# %% [markdown]
# # 2. Test Data

# %%
data_test.to_csv("fixed_test.csv")

file = open('fixed_test.csv', 'r')
log_test = dict()
with open('fixed_test.csv', 'r') as file:
    next(file)
    for line in file:
        line = line.strip()
        if len(line) == 0:
            continue
        parts = line.split(',')
        caseid = parts[2]
        
        task = parts[3]
        timestamp = parts[5]

        if caseid not in log_test:
            log_test[caseid] = [[],[]]

        log_test[caseid][0].append(task)
        log_test[caseid][1].append(timestamp)
        
file.close()

os.remove('fixed_test.csv')

# %%
"""Fixing a bug of cases that are in the test data but are incomplete due to the train-test split."""

bugs = []

for i in log_test.keys():
    if len(log_test[i][0]) == 1:
        bugs.append(i)
            
for x in bugs:
    del log_test[x]

# %%
for i in log_test.keys():
    current = log_test[i][0]  # current case' events
    
    real_next = current[1:]  # next real event
    real_next.append('New Case')  # adding a 'new case' as real next event for every last event
    log_test[i].append(real_next)

# %% [markdown]
# # 3. Storing the data

# %% [markdown]
# ## 3.1 TRAIN

# %%
event_list = []  # list of lists that contains all event names for every case, where each sublist is a new case.
for case in log.keys():
    event_list.append((log[case][0]))


events_longest_event = max(map(len,event_list))  # longest case

pos_events_train = []  # list of lists which has all event names for every position, where each sublist is a new position
for i in range(events_longest_event):  # creates a list every iteration which is appended to the above list
    pos_events_train.append([])
    for case in event_list:
        if (len(case)-1) >= i:
            pos_events_train[i].append(case[i])
        else:
            pass

# %%
events_train = {}

for i in range(len(pos_events_train)-1):
    events_train[i] = []
    
    previous_events = pos_events_train[i-1]
    current_events = pos_events_train[i]
    next_events = pos_events_train[i+1]
    
    events_train[i].append(previous_events)
    events_train[i].append(current_events)
    events_train[i].append(next_events)
events_train[0][0] = ['New Case'] * 120296

# %%
for i in events_train.keys():
    if len(events_train[i][1]) > len(events_train[i][2]):
        diff = len(events_train[i][1]) - len(events_train[i][2])
        for x in range(diff):
            events_train[i][2].append('New Case')

# %% [markdown]
# ## 3.2 TEST

# %%
event_list_test = []  # list of lists that contains all event names for every case, where each sublist is a new case.
for case in log_test.keys():
    event_list_test.append((log_test[case][0]))


events_longest_event_test = max(map(len,event_list_test))  # longest case

pos_events_test = []  # list of lists which has all event names for every position, where each sublist is a new position
for i in range(events_longest_event_test):  # creates a list every iteration which is appended to the above list
    pos_events_test.append([])
    for case in event_list_test:
        if (len(case)-1) >= i:
            pos_events_test[i].append(case[i])
        else:
            pass

# %%
events_test = {}

for i in range(len(pos_events_test)-1):
    events_test[i] = []
    previous_events = pos_events_test[i-1]
    current_events = pos_events_test[i]
    next_events = pos_events_test[i+1]
    
    events_test[i].append(previous_events)
    events_test[i].append(current_events)
    events_test[i].append(next_events)
events_test[0][0] =  ['New Case'] * len(events_test[0][0])

# %%
for i in events_test.keys():
    if len(events_test[i][1]) > len(events_test[i][2]):
        diff = len(events_test[i][1]) - len(events_test[i][2])
        for x in range(diff):
            events_test[i][2].append('New Case')

# %% [markdown]
# # 4. Training the decision trees

# %%
cases = list(data_train['event concept:name'].unique()) + list(data_test['event concept:name'].unique())  # list of all unique event names
cases.append('New Case')
cases = list(set(cases))
le = preprocessing.LabelEncoder()
le.fit(cases)  # encoding all event names into integers
# Out:
# LabelEncoder()

# %%
def decision_tree(pos):

    x_train= le.transform(events_train[pos][1]).reshape(-1, 1)
    x_previous = le.transform(events_train[pos][0]).reshape(-1 ,1)
    x_train_new = np.concatenate((x_train,x_previous), axis=1)
    y_train= le.transform(events_train[pos][2]).reshape(-1, 1)

    x_test= le.transform(events_test[pos][0]).reshape(-1, 1)
    y_test= le.transform(events_test[pos][1]).reshape(-1, 1)
    
    classifier = DecisionTreeClassifier()
    classifier.fit(x_train_new, y_train)
    
    return classifier

# %%
predictors = {}

for i in range(len(events_train)):
    predictors[i] = decision_tree(i)

# %% [markdown]
# # 5. Making Predictions

# %%
pbar = ProgressBar()

for i in pbar(log_test.keys()):
    current = log_test[i][0]
    predictions = []
    
    count = 0
    for j in range(len(current)):
        x = current[j]
        if j == 0:
            prev = 'New Case'
        else:
            prev = current[j-1]
            
        if count in predictors:
            tree = predictors[count]
            transf= le.transform([x]).reshape(-1, 1)
            transf_prev = le.transform([prev]).reshape(-1,1)
            trans = np.concatenate((transf, transf_prev), axis=1)
            prediction = tree.predict(trans)
            pred_string = le.inverse_transform(prediction)[0]
            count += 1
            predictions.append(pred_string)
        else:
            tree = predictors[count-1]
            transf= le.transform([x]).reshape(-1, 1)
            transf_prev = le.transform([prev]).reshape(-1,1)
            trans = np.concatenate((transf, transf_prev), axis=1)
            prediction = tree.predict(trans)
            pred_string = le.inverse_transform(prediction)[0]
            predictions.append(pred_string)
            
    
    log_test[i].append(predictions)
# Out:
# 100% |########################################################################|

# %%
log_test
# Out:
# {'A28905': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-09-25', '2010-01-19', '2010-08-02', '2010-09-04', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A28907': [['Create Fine', 'Send Fine'],
#   ['2009-09-25', '2010-01-19'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29038': [['Send Fine', 'Create Fine'],
#   ['2009-07-28', '2009-08-05'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A29040': [['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Payment',
#    'Payment'],
#   ['2009-07-28',
#    '2009-08-17',
#    '2009-10-16',
#    '2009-11-05',
#    '2010-02-02',
#    '2010-02-27'],
#   ['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Payment',
#    'Payment',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case',
#    'New Case']],
#  'A29041': [['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send for Credit Collection'],
#   ['2009-07-28', '2009-08-17', '2009-10-16', '2009-11-05', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29401': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-20', '2009-12-18', '2010-07-01', '2010-08-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29403': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-20', '2009-12-18', '2009-12-28', '2010-02-26', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29404': [['Create Fine', 'Send Fine'],
#   ['2009-08-20', '2009-12-18'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29406': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-21', '2009-12-18', '2010-07-01', '2010-08-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29410': [['Create Fine', 'Payment'],
#   ['2009-08-21', '2009-08-24'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29412': [['Create Fine', 'Payment'],
#   ['2009-08-21', '2009-08-21'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29414': [['Create Fine', 'Payment'],
#   ['2009-08-21', '2009-08-24'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29416': [['Create Fine',
#    'Send Fine',
#    'Add penalty',
#    'Insert Fine Notification',
#    'Send for Credit Collection'],
#   ['2009-08-21', '2009-12-18', '2010-03-13', '2010-12-01', '2012-03-26'],
#   ['Send Fine',
#    'Add penalty',
#    'Insert Fine Notification',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29417': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-24', '2009-12-18', '2010-08-01', '2010-09-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29418': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-08-24', '2009-12-18', '2009-12-29', '2010-02-27', '2010-08-06'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29419': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-24', '2009-12-18', '2009-12-31', '2010-01-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29421': [['Create Fine', 'Payment'],
#   ['2009-08-24', '2009-08-26'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29425': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-08-25', '2009-12-18', '2010-07-01', '2010-08-03', '2011-07-25'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29426': [['Create Fine', 'Payment'],
#   ['2009-08-25', '2009-08-27'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29427': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-08-25', '2009-12-18', '2009-12-28', '2010-02-26', '2010-02-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29429': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-26', '2009-12-18', '2010-05-01', '2010-06-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29431': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Insert Date Appeal to Prefecture',
#    'Add penalty',
#    'Send Appeal to Prefecture'],
#   ['2009-08-26',
#    '2009-12-18',
#    '2010-01-15',
#    '2010-02-23',
#    '2010-03-16',
#    '2010-03-22'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Insert Date Appeal to Prefecture',
#    'Add penalty',
#    'Send Appeal to Prefecture',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case',
#    'New Case']],
#  'A29433': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-26', '2009-12-18', '2010-01-24', '2010-03-25', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29434': [['Create Fine', 'Send Fine'],
#   ['2009-08-26', '2009-12-18'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29435': [['Create Fine', 'Payment'],
#   ['2009-08-26', '2009-08-29'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29436': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-26', '2009-12-18', '2009-12-23', '2010-02-21', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29447': [['Payment', 'Create Fine'],
#   ['2009-07-09', '2009-07-09'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A29450': [['Create Fine', 'Send Fine'],
#   ['2009-07-09', '2009-12-18'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29802': [['Create Fine', 'Payment'],
#   ['2009-09-18', '2009-10-19'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29803': [['Create Fine', 'Payment'],
#   ['2009-09-18', '2009-09-24'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29804': [['Create Fine', 'Payment'],
#   ['2009-09-18', '2009-09-22'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29805': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-09-25', '2010-01-19', '2010-01-28', '2010-03-29', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29807': [['Create Fine', 'Payment'],
#   ['2009-09-25', '2009-09-28'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29813': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-09-26', '2010-01-19', '2010-01-29', '2010-03-30', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29816': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-09-29', '2010-01-19', '2010-01-30', '2010-03-31', '2011-09-08'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29817': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-09-29', '2010-01-19', '2010-05-02', '2010-06-04', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29822': [['Create Fine', 'Payment'],
#   ['2009-09-10', '2009-10-30'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29825': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-09-10', '2010-01-19', '2010-03-02', '2010-04-04', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29826': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-09-10', '2010-01-19', '2010-01-28', '2010-03-29', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29829': [['Create Fine', 'Send Fine'],
#   ['2009-11-10', '2010-01-19'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29830': [['Payment', 'Create Fine'],
#   ['2009-10-15', '2009-11-10'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A29831': [['Create Fine', 'Send Fine'],
#   ['2009-11-10', '2010-01-19'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29834': [['Payment', 'Create Fine'],
#   ['2009-10-13', '2009-11-10'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A29836': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-11-10', '2010-01-19', '2010-01-29', '2010-03-30', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A29838': [['Create Fine', 'Payment'],
#   ['2009-10-13', '2009-10-15'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29839': [['Create Fine', 'Payment'],
#   ['2009-10-13', '2009-10-19'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29842': [['Create Fine', 'Send Fine'],
#   ['2009-10-24', '2010-01-19'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29843': [['Create Fine', 'Payment'],
#   ['2009-10-24', '2009-10-26'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29844': [['Create Fine', 'Payment'],
#   ['2009-10-24', '2009-10-30'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A29845': [['Create Fine', 'Send Fine'],
#   ['2009-10-25', '2010-01-19'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30233': [['Payment', 'Create Fine'],
#   ['2009-06-19', '2009-12-06'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A30235': [['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'Create Fine'],
#   ['2009-09-18', '2009-09-28', '2009-11-27', '2009-11-28', '2009-12-06'],
#   ['Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'Create Fine',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A30237': [['Create Fine', 'Payment'],
#   ['2009-06-16', '2009-06-19'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30238': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-06-16', '2009-09-18', '2009-09-26', '2009-11-25', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A30517': [['Create Fine', 'Payment'],
#   ['2009-07-26', '2009-07-30'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30520': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Insert Date Appeal to Prefecture',
#    'Send Appeal to Prefecture'],
#   ['2009-07-26',
#    '2009-09-12',
#    '2009-12-24',
#    '2010-02-22',
#    '2010-08-03',
#    '2010-09-04'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Insert Date Appeal to Prefecture',
#    'Send Appeal to Prefecture',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case',
#    'New Case']],
#  'A30521': [['Create Fine', 'Payment'],
#   ['2009-07-26', '2009-07-26'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30523': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-07-26', '2009-09-12', '2009-12-26', '2010-02-24', '2011-03-08'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A30524': [['Create Fine', 'Send Fine'],
#   ['2009-07-26', '2009-09-12'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30526': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-08', '2009-12-17', '2010-08-01', '2010-09-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A30534': [['Create Fine', 'Send Fine'],
#   ['2009-07-08', '2009-12-17'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30535': [['Create Fine', 'Payment'],
#   ['2009-07-08', '2009-08-22'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30538': [['Create Fine', 'Payment'],
#   ['2009-11-08', '2009-12-08'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30540': [['Create Fine', 'Send Fine'],
#   ['2009-08-13', '2009-12-17'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30541': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-08-13', '2009-12-17', '2009-12-28', '2010-02-26', '2011-01-09'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A30543': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-13', '2009-12-17', '2010-09-01', '2010-10-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A30545': [['Create Fine', 'Payment'],
#   ['2009-08-13', '2009-09-28'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30546': [['Create Fine', 'Send Fine'],
#   ['2009-08-13', '2009-12-17'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A30548': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-13', '2009-12-17', '2010-03-01', '2010-04-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A32816': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-18', '2009-07-03', '2009-08-17', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A32825': [['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send for Credit Collection'],
#   ['2009-07-20', '2009-07-24', '2009-09-22', '2009-10-04', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A35278': [['Create Fine', 'Send Fine'],
#   ['2009-07-05', '2009-07-28'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A35281': [['Send Fine', 'Create Fine'],
#   ['2009-07-28', '2009-08-05'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A35283': [['Create Fine', 'Payment'],
#   ['2009-09-05', '2009-11-05'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A35286': [['Send Fine', 'Create Fine'],
#   ['2009-07-28', '2009-10-05'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A35288': [['Create Fine', 'Payment'],
#   ['2009-10-05', '2009-11-05'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A35289': [['Create Fine', 'Payment'],
#   ['2009-10-05', '2009-11-05'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A35292': [['Send Fine', 'Create Fine'],
#   ['2009-07-28', '2009-11-05'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A35296': [['Send Fine', 'Create Fine'],
#   ['2009-07-28', '2009-11-05'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A35542': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-25', '2009-07-03', '2009-08-24', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A35545': [['Create Fine', 'Payment'],
#   ['2009-07-03', '2009-09-03'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A35546': [['Create Fine', 'Payment'],
#   ['2009-07-03', '2009-12-03'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A35547': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-28', '2009-07-03', '2009-08-27', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A35548': [['Create Fine', 'Send Fine'],
#   ['2009-07-03', '2009-12-06'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A35550': [['Create Fine', 'Payment'],
#   ['2009-07-03', '2009-09-03'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A35694': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-28', '2009-08-03', '2009-08-27', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A35696': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-03', '2009-11-11', '2009-11-26', '2010-01-25', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A35697': [['Payment', 'Create Fine'],
#   ['2009-07-05', '2009-08-03'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A35698': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-17', '2009-08-03', '2009-08-16', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A35699': [['Create Fine', 'Payment'],
#   ['2009-08-03', '2009-09-03'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A35754': [['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-26', '2009-08-25', '2009-09-03', '2009-12-06', '2010-10-15'],
#   ['Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A38281': [['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-26', '2009-08-25', '2009-10-03', '2009-12-06', '2010-10-15'],
#   ['Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A38282': [['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-17', '2009-08-16', '2009-10-03', '2009-12-06', '2010-10-15'],
#   ['Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A38293': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-04', '2009-07-20', '2009-07-28', '2009-09-26', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A38295': [['Send Fine', 'Create Fine'],
#   ['2009-07-20', '2009-08-04'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A38296': [['Send Fine', 'Create Fine'],
#   ['2009-07-20', '2009-11-04'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A38374': [['Create Fine', 'Payment'],
#   ['2009-09-01', '2009-12-01'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38379': [['Create Fine', 'Payment'],
#   ['2009-10-01', '2009-11-01'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38385': [['Payment', 'Create Fine'],
#   ['2009-12-01', '2009-12-01'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A38543': [['Create Fine', 'Send Fine'],
#   ['2009-10-01', '2009-12-05'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38544': [['Payment', 'Create Fine'],
#   ['2009-10-01', '2009-10-01'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A38552': [['Create Fine', 'Send Fine'],
#   ['2009-07-17', '2009-11-28'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38555': [['Create Fine', 'Payment'],
#   ['2009-10-23', '2009-10-30'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38556': [['Create Fine', 'Payment'],
#   ['2009-10-23', '2009-10-30'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38557': [['Create Fine', 'Send Fine'],
#   ['2009-10-23', '2010-01-19'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38610': [['Payment', 'Create Fine'],
#   ['2009-08-02', '2009-08-02'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A38622': [['Send Fine', 'Create Fine'],
#   ['2009-09-18', '2009-10-02'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A38658': [['Create Fine', 'Send Fine'],
#   ['2009-09-01', '2009-12-05'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38666': [['Create Fine', 'Send Fine'],
#   ['2009-10-01', '2009-12-05'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38675': [['Create Fine', 'Payment'],
#   ['2009-11-01', '2009-12-01'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38680': [['Create Fine', 'Payment'],
#   ['2009-11-01', '2009-12-01'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38681': [['Create Fine', 'Send Fine'],
#   ['2009-12-01', '2009-12-05'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38734': [['Payment', 'Create Fine'],
#   ['2009-09-02', '2009-09-02'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A38735': [['Create Fine', 'Payment'],
#   ['2009-11-02', '2009-12-02'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38765': [['Create Fine', 'Payment'],
#   ['2009-07-02', '2009-11-02'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A38997': [['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-16', '2009-08-15', '2009-09-03', '2009-12-06', '2010-10-15'],
#   ['Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A38999': [['Create Fine', 'Payment'],
#   ['2009-09-03', '2009-12-03'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39000': [['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-27', '2009-08-26', '2009-09-03', '2009-12-06', '2010-10-15'],
#   ['Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39029': [['Create Fine', 'Payment'],
#   ['2009-07-02', '2009-11-02'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39031': [['Create Fine', 'Payment'],
#   ['2009-07-02', '2009-10-02'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39040': [['Create Fine', 'Payment'],
#   ['2009-08-02', '2009-10-02'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39124': [['Create Fine', 'Payment'],
#   ['2009-07-03', '2009-11-03'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39126': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-27', '2009-07-03', '2009-08-26', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39129': [['Payment', 'Create Fine'],
#   ['2009-10-03', '2009-10-03'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A39132': [['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-26', '2009-08-25', '2009-10-03', '2009-12-06', '2010-10-15'],
#   ['Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39133': [['Create Fine', 'Send Fine'],
#   ['2009-10-03', '2009-12-06'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39168': [['Create Fine', 'Payment'],
#   ['2009-07-01', '2009-10-01'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39186': [['Create Fine', 'Send Fine'],
#   ['2009-09-01', '2009-12-05'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39192': [['Create Fine', 'Payment'],
#   ['2009-10-01', '2009-11-01'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39200': [['Create Fine', 'Send Fine'],
#   ['2009-11-01', '2009-12-05'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39218': [['Create Fine', 'Payment'],
#   ['2009-08-02', '2009-09-02'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39222': [['Payment', 'Create Fine'],
#   ['2009-09-02', '2009-09-02'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A39251': [['Create Fine', 'Payment'],
#   ['2009-09-03', '2009-12-03'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39252': [['Create Fine', 'Send Fine'],
#   ['2009-09-03', '2009-12-06'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39318': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-06-28', '2009-09-25', '2009-10-14', '2009-12-13', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39321': [['Create Fine', 'Send Fine'],
#   ['2009-07-06', '2009-09-18'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39322': [['Create Fine', 'Send Fine'],
#   ['2009-09-07', '2009-11-11'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39323': [['Create Fine',
#    'Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-16', '2009-10-12', '2009-11-28', '2010-08-02', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39324': [['Create Fine', 'Send Fine'],
#   ['2009-07-22', '2009-11-28'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39327': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-26', '2009-09-12', '2009-12-16', '2010-02-14', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39328': [['Create Fine',
#    'Send Fine',
#    'Add penalty',
#    'Insert Fine Notification',
#    'Send for Credit Collection'],
#   ['2009-07-16', '2009-11-28', '2010-03-13', '2010-12-01', '2012-03-26'],
#   ['Send Fine',
#    'Add penalty',
#    'Insert Fine Notification',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39331': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-09-08', '2009-12-17', '2009-12-28', '2010-02-26', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39333': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-09', '2009-12-18', '2010-01-13', '2010-03-14', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39372': [['Payment', 'Create Fine'],
#   ['2009-08-04', '2009-08-04'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A39375': [['Create Fine', 'Payment'],
#   ['2009-08-04', '2009-08-05'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39377': [['Create Fine', 'Payment'],
#   ['2009-08-04', '2009-09-04'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39433': [['Create Fine', 'Send Fine'],
#   ['2009-07-04', '2009-07-20'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39434': [['Create Fine', 'Payment'],
#   ['2009-07-04', '2009-10-04'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39444': [['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Payment'],
#   ['2009-07-20', '2009-07-24', '2009-09-22', '2009-12-04', '2011-01-08'],
#   ['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Payment',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39453': [['Create Fine', 'Send Fine'],
#   ['2009-11-01', '2009-12-05'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39464': [['Create Fine', 'Payment'],
#   ['2009-11-01', '2009-12-01'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39537': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-19', '2009-07-03', '2009-08-18', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39538': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-28', '2009-07-03', '2009-08-27', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39540': [['Insert Fine Notification',
#    'Create Fine',
#    'Appeal to Judge',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-27',
#    '2009-07-03',
#    '2009-07-28',
#    '2009-08-26',
#    '2009-12-06',
#    '2012-03-26'],
#   ['Create Fine',
#    'Appeal to Judge',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case',
#    'New Case']],
#  'A39543': [['Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'Create Fine',
#    'Payment',
#    'Send Fine'],
#   ['2009-06-18',
#    '2009-08-17',
#    '2009-10-19',
#    '2009-11-03',
#    '2009-11-12',
#    '2009-12-06'],
#   ['Add penalty',
#    'Payment',
#    'Create Fine',
#    'Payment',
#    'Send Fine',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case',
#    'New Case']],
#  'A39544': [['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-17', '2009-08-16', '2009-12-03', '2009-12-06', '2010-10-15'],
#   ['Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39545': [['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-16', '2009-08-15', '2009-12-03', '2009-12-06', '2010-10-15'],
#   ['Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39585': [['Create Fine', 'Send Fine'],
#   ['2009-07-04', '2009-07-20'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39590': [['Send Fine',
#    'Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-20', '2009-07-24', '2009-08-04', '2009-09-22', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39591': [['Send Fine',
#    'Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-20', '2009-07-28', '2009-08-04', '2009-09-26', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39600': [['Send Fine', 'Create Fine'],
#   ['2009-07-20', '2009-11-04'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A39670': [['Create Fine', 'Send Fine'],
#   ['2009-10-05', '2009-11-28'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39673': [['Send Fine',
#    'Add penalty',
#    'Create Fine',
#    'Insert Fine Notification',
#    'Send for Credit Collection'],
#   ['2009-07-28', '2009-10-10', '2009-11-05', '2009-11-08', '2012-03-26'],
#   ['Add penalty',
#    'Create Fine',
#    'Insert Fine Notification',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39674': [['Send Fine', 'Create Fine'],
#   ['2009-07-28', '2009-11-05'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A39748': [['Create Fine', 'Payment'],
#   ['2009-07-05', '2009-08-05'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39749': [['Payment', 'Create Fine'],
#   ['2009-06-29', '2009-10-05'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A39851': [['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send for Credit Collection'],
#   ['2009-07-20', '2009-07-24', '2009-09-22', '2009-11-04', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39852': [['Payment', 'Create Fine'],
#   ['2009-06-19', '2009-11-04'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A39913': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-17', '2009-08-03', '2009-08-16', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39920': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-17', '2009-08-03', '2009-08-16', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39922': [['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-17', '2009-08-03', '2009-08-16', '2009-12-06', '2010-10-15'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39923': [['Create Fine', 'Payment'],
#   ['2009-08-03', '2009-10-03'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39929': [['Create Fine', 'Payment'],
#   ['2009-09-03', '2009-11-03'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39930': [['Insert Fine Notification',
#    'Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-06-18', '2009-08-17', '2009-10-03', '2009-12-06', '2010-10-15'],
#   ['Add penalty',
#    'Create Fine',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39931': [['Create Fine', 'Send Fine'],
#   ['2009-11-03', '2009-12-06'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39955': [['Send Fine', 'Create Fine'],
#   ['2009-07-28', '2009-08-05'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A39960': [['Send Fine',
#    'Create Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-29', '2009-08-06', '2009-08-14', '2009-10-13', '2012-03-26'],
#   ['Create Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39970': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-10-07', '2009-11-11', '2009-11-16', '2010-01-15', '2011-07-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39971': [['Send Fine',
#    'Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-11-11', '2009-11-26', '2009-12-07', '2010-01-25', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39976': [['Create Fine', 'Send Fine'],
#   ['2009-07-25', '2009-09-12'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39978': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-10-09', '2010-01-19', '2010-01-28', '2010-03-29', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39979': [['Create Fine', 'Send Fine'],
#   ['2009-10-09', '2010-01-19'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A39981': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-09-20', '2010-01-19', '2010-03-02', '2010-04-04', '2011-03-08'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A39982': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-10', '2010-01-19', '2010-07-02', '2010-08-04', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A40001': [['Send Fine',
#    'Create Fine',
#    'Add penalty',
#    'Send Appeal to Prefecture',
#    'Insert Fine Notification',
#    'Insert Date Appeal to Prefecture'],
#   ['2009-07-28',
#    '2009-10-05',
#    '2009-11-10',
#    '2009-11-23',
#    '2009-12-08',
#    '2009-12-10'],
#   ['Create Fine',
#    'Add penalty',
#    'Send Appeal to Prefecture',
#    'Insert Fine Notification',
#    'Insert Date Appeal to Prefecture',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case',
#    'New Case']],
#  'A40002': [['Send Fine',
#    'Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-28', '2009-08-17', '2009-10-05', '2009-10-16', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Create Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A40035': [['Create Fine', 'Send Fine'],
#   ['2009-07-06', '2009-09-18'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A40039': [['Create Fine', 'Send Fine'],
#   ['2009-07-06', '2009-07-29'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A40041': [['Create Fine',
#    'Add penalty',
#    'Insert Fine Notification',
#    'Send Fine',
#    'Send for Credit Collection'],
#   ['2009-07-06', '2009-07-12', '2009-08-10', '2009-09-18', '2012-03-26'],
#   ['Add penalty',
#    'Insert Fine Notification',
#    'Send Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A40042': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-06', '2009-09-18', '2009-09-28', '2009-11-27', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A40044': [['Add penalty',
#    'Insert Fine Notification',
#    'Send Fine',
#    'Create Fine',
#    'Send for Credit Collection'],
#   ['2009-08-12', '2009-09-10', '2009-09-18', '2009-12-06', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Send Fine',
#    'Create Fine',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Insert Fine Notification',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A40046': [['Send Fine', 'Create Fine'],
#   ['2009-07-29', '2009-12-06'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A40057': [['Create Fine', 'Payment'],
#   ['2009-08-02', '2009-10-02'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A40059': [['Create Fine', 'Payment'],
#   ['2009-08-02', '2009-09-02'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A40076': [['Create Fine', 'Payment'],
#   ['2009-11-02', '2009-11-02'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A40081': [['Send Fine',
#    'Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-11-11', '2009-11-29', '2009-12-02', '2010-01-28', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Create Fine',
#    'Add penalty',
#    'Send for Credit Collection',
# ...
#   ['2009-10-17', '2010-01-19', '2010-03-02', '2010-04-04', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43877': [['Create Fine', 'Payment'],
#   ['2009-10-18', '2009-10-20'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43882': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-10-18', '2010-01-19', '2010-01-28', '2010-03-29', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43883': [['Create Fine', 'Payment'],
#   ['2009-10-18', '2009-10-20'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43887': [['Create Fine',
#    'Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-10-19', '2010-03-20', '2010-04-03', '2010-05-19', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43888': [['Create Fine', 'Payment'],
#   ['2009-10-19', '2009-10-19'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43889': [['Create Fine', 'Payment'],
#   ['2009-10-19', '2009-10-26'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43890': [['Create Fine', 'Send Fine'],
#   ['2009-10-23', '2010-01-19'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43891': [['Create Fine', 'Payment'],
#   ['2009-10-23', '2009-10-27'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43893': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-10-26', '2010-01-19', '2010-01-29', '2010-03-30', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43901': [['Create Fine', 'Payment'],
#   ['2009-07-21', '2009-07-27'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43902': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-07-21', '2009-11-28', '2009-12-30', '2010-02-28', '2011-07-30'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43904': [['Create Fine',
#    'Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-21', '2009-09-12', '2009-11-28', '2010-07-02', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43905': [['Create Fine', 'Payment'],
#   ['2009-07-21', '2009-11-08'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43907': [['Create Fine',
#    'Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Payment'],
#   ['2009-07-21', '2009-10-12', '2009-11-28', '2010-08-02', '2010-11-03'],
#   ['Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43908': [['Create Fine',
#    'Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-22', '2009-09-12', '2009-11-28', '2010-07-02', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43912': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-24', '2009-11-28', '2009-12-20', '2010-02-18', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43914': [['Create Fine', 'Payment'],
#   ['2009-07-25', '2009-07-31'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43917': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-25', '2009-09-12', '2009-12-14', '2010-12-02', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43919': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-26', '2009-09-12', '2009-12-14', '2010-12-02', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43920': [['Create Fine', 'Payment'],
#   ['2009-07-26', '2009-09-21'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43921': [['Create Fine', 'Payment'],
#   ['2009-07-26', '2009-07-29'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43922': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-26', '2009-09-12', '2009-12-14', '2010-12-02', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43923': [['Create Fine', 'Send Fine'],
#   ['2009-07-26', '2010-04-03'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43927': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-26', '2009-09-12', '2009-12-24', '2010-02-22', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43930': [['Create Fine', 'Send Fine'],
#   ['2009-07-26', '2009-09-12'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43931': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-26', '2009-09-12', '2009-12-24', '2010-02-22', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43932': [['Create Fine', 'Payment'],
#   ['2009-07-26', '2009-07-27'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43933': [['Create Fine', 'Payment'],
#   ['2009-07-26', '2009-07-27'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43935': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-26', '2009-09-12', '2009-12-24', '2010-02-22', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43936': [['Create Fine',
#    'Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-26', '2010-03-18', '2010-04-03', '2010-05-17', '2012-03-26'],
#   ['Insert Fine Notification',
#    'Send Fine',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43938': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-28', '2009-09-12', '2009-12-24', '2010-02-22', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43940': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-29', '2009-09-12', '2009-12-25', '2010-02-23', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43942': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-07-29', '2009-09-12', '2009-12-16', '2010-02-14', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43943': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'Payment'],
#   ['2009-07-31',
#    '2009-09-12',
#    '2009-12-15',
#    '2010-02-13',
#    '2010-08-27',
#    '2010-09-22'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case',
#    'New Case']],
#  'A43964': [['Create Fine', 'Send Fine'],
#   ['2009-08-08', '2009-12-17'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43965': [['Create Fine', 'Send Fine'],
#   ['2009-08-08', '2009-12-17'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43966': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-08-08', '2009-12-17', '2009-12-29', '2010-02-27', '2011-09-06'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43968': [['Create Fine', 'Send Fine'],
#   ['2009-08-08', '2009-12-17'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43969': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Insert Date Appeal to Prefecture',
#    'Add penalty',
#    'Send Appeal to Prefecture'],
#   ['2009-08-08',
#    '2009-12-17',
#    '2009-12-28',
#    '2010-02-18',
#    '2010-02-26',
#    '2010-08-05'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Insert Date Appeal to Prefecture',
#    'Add penalty',
#    'Send Appeal to Prefecture',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case',
#    'New Case']],
#  'A43972': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment'],
#   ['2009-09-08', '2009-12-17', '2010-07-01', '2010-08-03', '2011-10-08'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Payment',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43974': [['Create Fine', 'Payment'],
#   ['2009-09-08', '2009-10-08'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43975': [['Payment', 'Create Fine'],
#   ['2009-08-27', '2009-09-08'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A43976': [['Payment', 'Create Fine'],
#   ['2009-09-08', '2009-09-08'],
#   ['Create Fine', 'New Case'],
#   ['Create Fine', 'New Case']],
#  'A43977': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty'],
#   ['2009-09-08', '2009-12-17', '2009-12-28', '2010-02-26'],
#   ['Send Fine', 'Insert Fine Notification', 'Add penalty', 'New Case'],
#   ['Send Fine', 'New Case', 'Add penalty', 'Send for Credit Collection']],
#  'A43978': [['Create Fine', 'Payment'],
#   ['2009-09-08', '2009-09-17'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43979': [['Create Fine', 'Send Fine'],
#   ['2009-09-08', '2009-12-17'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43981': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-09-08', '2009-12-17', '2009-12-29', '2010-02-27', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43983': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-09-08', '2009-12-17', '2010-07-01', '2010-08-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43984': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-09-08', '2009-12-17', '2010-07-01', '2010-08-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43986': [['Create Fine', 'Payment'],
#   ['2009-09-08', '2009-10-09'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43987': [['Create Fine', 'Send Fine'],
#   ['2009-11-08', '2009-12-17'],
#   ['Send Fine', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43988': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-11-08', '2009-12-17', '2009-12-28', '2010-02-26', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43989': [['Create Fine', 'Payment'],
#   ['2009-11-08', '2009-12-08'],
#   ['Payment', 'New Case'],
#   ['Send Fine', 'New Case']],
#  'A43990': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-11-08', '2009-12-17', '2009-12-28', '2010-02-26', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43991': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-14', '2009-12-17', '2009-12-28', '2010-02-26', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  'A43992': [['Create Fine',
#    'Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection'],
#   ['2009-08-14', '2009-12-17', '2010-07-01', '2010-08-03', '2012-03-26'],
#   ['Send Fine',
#    'Insert Fine Notification',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case'],
#   ['Send Fine',
#    'New Case',
#    'Add penalty',
#    'Send for Credit Collection',
#    'New Case']],
#  ...}

# %% [markdown]
# # 6. Evaluating Accuracy

# %%
case_names = []
event_names = []
timestamp = []
p_event = []
current_real = []

for i in log_test.keys():
    for x in range(len(log_test[i][0])):
        case_names.append(i)
        event_names.append(log_test[i][0][x])
        timestamp.append(log_test[i][1][x])
        p_event.append(log_test[i][3][x])
        current_real.append(log_test[i][2][x])


frame_dict = {'Case_ID': case_names, 'Event_Name': event_names,
              'TimeStamp': timestamp, 'Current_Event': current_real, 'Predicted_Event': p_event}
predicted_df = pd.DataFrame.from_dict(frame_dict)

event_real = np.array(predicted_df['Current_Event'])
event_pred = np.array(predicted_df['Predicted_Event'])

acc = accuracy_score(event_real, event_pred)
print('Accuracy for event prediction TEST SET: {}%'.format(round(acc, 2) * 100))
# Out:
# Accuracy for event prediction TEST SET: 56.99999999999999%

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 294.3284430503845 seconds ---

# %%
predicted_df
# Out:
#       Case_ID                  Event_Name   TimeStamp  \
# 0      A28905                 Create Fine  2009-09-25
# 1      A28905                   Send Fine  2010-01-19
# 2      A28905    Insert Fine Notification  2010-08-02
# 3      A28905                 Add penalty  2010-09-04
# 4      A28905  Send for Credit Collection  2012-03-26
# ...       ...                         ...         ...
# 96156  V19305   Send Appeal to Prefecture  2012-02-24
# 96157  V19308                 Create Fine  2011-07-10
# 96158  V19308                   Send Fine  2012-01-30
# 96159  V19308    Insert Fine Notification  2012-02-24
# 96160  V19308                 Add penalty  2012-04-24
#
#                     Current_Event             Predicted_Event
# 0                       Send Fine                   Send Fine
# 1        Insert Fine Notification                    New Case
# 2                     Add penalty                 Add penalty
# 3      Send for Credit Collection  Send for Credit Collection
# 4                        New Case                    New Case
# ...                           ...                         ...
# 96156                    New Case                    New Case
# 96157                   Send Fine                   Send Fine
# 96158    Insert Fine Notification                    New Case
# 96159                 Add penalty                 Add penalty
# 96160                    New Case  Send for Credit Collection
#
# [96161 rows x 5 columns]
