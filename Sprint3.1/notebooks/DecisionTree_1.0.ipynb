# %% [markdown]
# # Decision Trees for predicting the next event of a case
#
# Currently the only tree that works is for position 0.
#
# Issues occur for the other positions because the x_train and y_train have different length.

# %%
import os
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
os.chdir("../")

# %%
data_train = pd.read_csv('./data/road-train-pre.csv', error_bad_lines=False)
data_test = pd.read_csv('./data/road-test-pre.csv', error_bad_lines=False)

# %%
data_train['event time:timestamp'] = pd.to_datetime(data_train['event time:timestamp'])
data_train = data_train.sort_values(by=['case concept:name', 'event time:timestamp'])

# %%
data_test['event time:timestamp'] = pd.to_datetime(data_test['event time:timestamp'])
data_test = data_test.sort_values(by=['case concept:name', 'event time:timestamp'])

# %% [markdown]
# # Train Data

# %%
data_train.to_csv("fixed.csv")

file = open('fixed.csv', 'r')
log = dict()
with open('fixed.csv', 'r') as file:
    next(file)
    for line in file:
        line = line.strip()
        if len(line) == 0:
            continue
        parts = line.split(',')
        caseid = parts[2]

        task = parts[3]
        timestamp = parts[5]

        if caseid not in log:
            log[caseid] = [[],[]]

        log[caseid][0].append(task)
        log[caseid][1].append(timestamp)
        
file.close()

os.remove('fixed.csv')

# %%
for i in log.keys():
    current = log[i][0]  # recording the current case' events
    
    real_next = current[1:]  # next real event
    real_next.append('New Case')  # adding a 'new case' as real next event for every last event
    
    log[i].append(real_next)  # adding the real next events to the log file

# %% [markdown]
# # Test Data

# %%
data_test.to_csv("fixed_test.csv")

file = open('fixed_test.csv', 'r')
log_test = dict()
with open('fixed_test.csv', 'r') as file:
    next(file)
    for line in file:
        line = line.strip()
        if len(line) == 0:
            continue
        parts = line.split(',')
        caseid = parts[2]
        
        task = parts[3]
        timestamp = parts[5]

        if caseid not in log_test:
            log_test[caseid] = [[],[]]

        log_test[caseid][0].append(task)
        log_test[caseid][1].append(timestamp)
        
file.close()

os.remove('fixed_test.csv')

# %%
"""Fixing a bug of cases that are in the test data but are incomplete due to the train-test split."""

bugs = []

for i in log_test.keys():
    if len(log_test[i][0]) == 1:
        bugs.append(i)
            
for x in bugs:
    del log_test[x]

# %%
for i in log_test.keys():
    current = log_test[i][0]  # current case' events
    
    real_next = current[1:]  # next real event
    real_next.append('New Case')  # adding a 'new case' as real next event for every last event
    if len(current) != len(real_next):
        print('Different length')
    log_test[i].append(real_next)

# %% [markdown]
# # Decision trees for every position

# %%
event_list = []  # list of lists that contains all event names for every case, where each sublist is a new case.
for case in log.keys():
    event_list.append((log[case][0]))


events_longest_event = max(map(len,event_list))  # longest case

pos_events = []  # list of lists which has all event names for every position, where each sublist is a new position
for i in range(events_longest_event):  # creates a list every iteration which is appended to the above list
    pos_events.append([])
    for case in event_list:
        if (len(case)-1) >= i:
            pos_events[i].append(case[i])
        else:
            pass

# %%
event_list_test = []  # list of lists that contains all event names for every case, where each sublist is a new case.
for case in log_test.keys():
    event_list_test.append((log_test[case][0]))


events_longest_event_test = max(map(len,event_list_test))  # longest case

pos_events_test = []  # list of lists which has all event names for every position, where each sublist is a new position
for i in range(events_longest_event_test):  # creates a list every iteration which is appended to the above list
    pos_events_test.append([])
    for case in event_list_test:
        if (len(case)-1) >= i:
            pos_events_test[i].append(case[i])
        else:
            pass

# %% [markdown]
# Stored_Data = { position: [ [ events ], [ next_real_events ] ] }

# %% [markdown]
# Position Events = [ [ ]...,[ ] ]   sublist for every position

# %%
events_test = {}

for i in range(len(pos_events_test)):
    events_test[i] = []
    current_events = pos_events_test[i]
    
    print(pos_events_test[i])
# Out:
# ['Create Fine', 'Create Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Payment', 'Create Fine', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Payment', 'Send Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Send Fine', 'Create Fine', 'Send Fine', 'Create Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Send Fine', 'Send Fine', 'Insert Fine Notification', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Create Fine', 'Payment', 'Insert Fine Notification', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Create Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Payment', 'Create Fine', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Payment', 'Send Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Payment', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Create Fine', 'Insert Fine Notification', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Payment', 'Insert Fine Notification', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Create Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Payment', 'Send Fine', 'Payment', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Create Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Add penalty', 'Send Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Send Fine', 'Create Fine', 'Insert Fine Notification', 'Create Fine', 'Insert Fine Notification', 'Add penalty', 'Insert Fine Notification', 'Insert Fine Notification', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Payment', 'Payment', 'Create Fine', 'Send Fine', 'Create Fine', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Send Fine', 'Send Fine', 'Insert Fine Notification', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Create Fine', 'Insert Fine Notification', 'Create Fine', 'Create Fine', 'Create Fine', ...
# ['Send Fine', 'Send Fine', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Payment', 'Payment', 'Payment', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Payment', 'Send Fine', 'Payment', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Payment', 'Send Fine', 'Create Fine', 'Send Fine', 'Payment', 'Payment', 'Payment', 'Send Fine', 'Payment', 'Send Fine', 'Send Fine', 'Send Fine', 'Payment', 'Send Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Send Fine', 'Create Fine', 'Send Fine', 'Payment', 'Payment', 'Send Fine', 'Payment', 'Payment', 'Send Fine', 'Create Fine', 'Insert Fine Notification', 'Payment', 'Send Fine', 'Payment', 'Send Fine', 'Payment', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Payment', 'Payment', 'Send Fine', 'Send Fine', 'Send Fine', 'Payment', 'Send Fine', 'Send Fine', 'Create Fine', 'Insert Fine Notification', 'Send Fine', 'Create Fine', 'Payment', 'Create Fine', 'Payment', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Payment', 'Payment', 'Create Fine', 'Send Fine', 'Payment', 'Create Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Payment', 'Add penalty', 'Add penalty', 'Add penalty', 'Send Fine', 'Create Fine', 'Create Fine', 'Payment', 'Payment', 'Create Fine', 'Send Fine', 'Create Fine', 'Send Fine', 'Payment', 'Payment', 'Send Fine', 'Create Fine', 'Create Fine', 'Send Fine', 'Send Fine', 'Payment', 'Payment', 'Send Fine', 'Create Fine', 'Payment', 'Payment', 'Add penalty', 'Payment', 'Add penalty', 'Payment', 'Payment', 'Payment', 'Payment', 'Create Fine', 'Create Fine', 'Add penalty', 'Send Fine', 'Payment', 'Send Fine', 'Payment', 'Send Fine', 'Payment', 'Create Fine', 'Payment', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Insert Fine Notification', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Payment', 'Payment', 'Send Fine', 'Payment', 'Insert Fine Notification', 'Send Fine', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Send Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Create Fine', 'Send Fine', 'Add penalty', 'Create Fine', 'Payment', 'Create Fine', 'Insert Fine Notification', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Payment', 'Payment', 'Add penalty', 'Send Fine', 'Create Fine', 'Create Fine', 'Send Fine', 'Insert Fine Notification', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Insert Fine Notification', 'Send Fine', 'Send Fine', 'Add penalty', 'Send Fine', 'Insert Fine Notification', 'Create Fine', 'Payment', 'Payment', 'Payment', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Send Fine', 'Create Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Add penalty', 'Add penalty', 'Send Fine', 'Send Fine', 'Add penalty', 'Send Fine', 'Send Fine', 'Payment', 'Insert Fine Notification', 'Send Fine', 'Create Fine', 'Send Fine', 'Payment', 'Send Fine', 'Send Fine', 'Create Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Payment', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Payment', 'Payment', 'Send Fine', 'Add penalty', 'Send Fine', 'Payment', 'Send Fine', 'Payment', 'Payment', 'Send Fine', 'Send Fine', 'Payment', 'Add penalty', 'Payment', 'Send Fine', 'Add penalty', 'Send Fine', 'Add penalty', 'Send Fine', 'Create Fine', 'Add penalty', 'Payment', 'Insert Fine Notification', 'Insert Fine Notification', 'Create Fine', 'Payment', 'Insert Fine Notification', 'Create Fine', 'Insert Fine Notification', 'Send Fine', 'Send Fine', 'Payment', 'Send Fine', 'Add penalty', 'Payment', 'Send Fine', 'Payment', 'Send Fine', 'Payment', 'Payment', 'Create Fine', 'Send Fine', ' ...
# ['Insert Fine Notification', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Create Fine', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Create Fine', 'Create Fine', 'Add penalty', 'Create Fine', 'Insert Fine Notification', 'Send Fine', 'Insert Fine Notification', 'Add penalty', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Add penalty', 'Appeal to Judge', 'Payment', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Create Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Send Fine', 'Create Fine', 'Add penalty', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Payment', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Insert Fine Notification', 'Create Fine', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Payment', 'Insert Fine Notification', 'Add penalty', 'Create Fine', 'Add penalty', 'Create Fine', 'Insert Date Appeal to Prefecture', 'Create Fine', 'Create Fine', 'Create Fine', 'Add penalty', 'Add penalty', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Send Fine', 'Send Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Create Fine', 'Create Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Create Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Send Fine', 'Add penalty', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Create Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Add penalty', 'Add penalty', 'Create Fine', 'Add penalty', 'Payment', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification', 'Insert Fine Notification' ...
# ['Add penalty', 'Create Fine', 'Create Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Date Appeal to Prefecture', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Payment', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Send Fine', 'Create Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Add penalty', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Add penalty', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Create Fine', 'Send Fine', 'Send Fine', 'Add penalty', 'Create Fine', 'Send Fine', 'Send Fine', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Create Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Send Appeal to Prefecture', 'Add penalty', 'Send Fine', 'Add penalty', 'Create Fine', 'Add penalty', 'Create Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Add penalty', 'Send Fine', 'Add penalty', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Send Fine', 'Create Fine', 'Create Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Send Fine', 'Send Fine', 'Payment', 'Send Fine', 'Create Fine', 'Send Fine', 'Send Fine', 'Add penalty', 'Create Fine', 'Create Fine', 'Add penalty', 'Add penalty', 'Send Fine', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Add penalty', 'Send Fine', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Add penalty', 'Send Fine', 'Send Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Create Fine', 'Create Fine', 'Add penalty', 'Create Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Send Fine', 'Send Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Create Fine', 'Send Fine', 'Send Fine', 'Insert Fine Notification', 'Insert Date Appeal to Prefecture', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Date Appeal to Prefecture', 'Add penalty', 'Add penalty', 'Send Fine', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Date Appeal to Prefecture', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Add penalty', 'Insert Fine Notification', 'Add penalty', 'Ad ...
# ['Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Payment', 'Payment', 'Send for Credit Collection', 'Add penalty', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Create Fine', 'Send for Credit Collection', 'Insert Date Appeal to Prefecture', 'Payment', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send Fine', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Insert Fine Notification', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Create Fine', 'Send for Credit Collection', 'Send Fine', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Payment', 'Add penalty', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send f ...
# ['Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send for Credit Collection', 'Send Fine', 'Insert Date Appeal to Prefecture', 'Add penalty', 'Add penalty', 'Add penalty', 'Send Fine', 'Send Appeal to Prefecture', 'Send for Credit Collection', 'Payment', 'Send Appeal to Prefecture', 'Payment', 'Payment', 'Payment', 'Send for Credit Collection', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Add penalty', 'Insert Date Appeal to Prefecture', 'Send for Credit Collection', 'Payment', 'Send Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Payment', 'Send for Credit Collection', 'Add penalty', 'Add penalty', 'Insert Date Appeal to Prefecture', 'Send for Credit Collection', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Payment', 'Insert Date Appeal to Prefecture', 'Payment', 'Send Appeal to Prefecture', 'Add penalty', 'Payment', 'Payment', 'Payment', 'Payment', 'Send for Credit Collection', 'Add penalty', 'Add penalty', 'Payment', 'Send for Credit Collection', 'Add penalty', 'Payment', 'Payment', 'Payment', 'Receive Result Appeal from Prefecture', 'Insert Fine Notification', 'Payment', 'Send Appeal to Prefecture', 'Receive Result Appeal from Prefecture', 'Add penalty', 'Insert Date Appeal to Prefecture', 'Add penalty', 'Payment', 'Payment', 'Add penalty', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Send Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Create Fine', 'Receive Result Appeal from Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Insert Date Appeal to Prefecture', 'Send for Credit Collection', 'Payment', 'Payment', 'Send for Credit Collection', 'Payment', 'Send Appeal to Prefecture', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send Appeal to Prefecture', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Payment', 'Payment', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Add penalty', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Send Appeal to Prefecture', 'Add penalty', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Send Fine', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Insert Date Appeal to Prefecture', 'Send for Credit Collection', 'Payment', 'Add penalty', 'Payment', 'Send Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Receive Result Appeal from Prefecture', 'Send Appeal to Prefecture', 'Receive Result Appeal from Prefecture', 'Add penalty', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Add penalty', 'Payment', 'Payment', 'Payment', 'Send Appeal to Prefecture', 'Add penalty', 'Payment', 'Create Fine', 'Payment', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Add penalty', 'Add penalty', 'Payment', 'Payment', 'Add penalty', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Payment', 'Add penalty', 'Add penalty', 'Payment', 'Payment', 'Payment' ...
# ['Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Payment', 'Add penalty', 'Send for Credit Collection', 'Payment', 'Receive Result Appeal from Prefecture', 'Payment', 'Payment', 'Payment', 'Send Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Payment', 'Create Fine', 'Receive Result Appeal from Prefecture', 'Send Fine', 'Receive Result Appeal from Prefecture', 'Add penalty', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Payment', 'Payment', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Insert Date Appeal to Prefecture', 'Payment', 'Payment', 'Payment', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Payment', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Payment', 'Insert Fine Notification', 'Payment', 'Notify Result Appeal to Offender', 'Appeal to Judge', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Payment', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Payment', 'Receive Result Appeal from Prefecture', 'Add penalty', 'Receive Result Appeal from Prefecture', 'Send Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Payment', 'Send Appeal to Prefecture', 'Payment', 'Payment', 'Insert Fine Notification', 'Insert Fine Notification', 'Send for Credit Collection', 'Payment', 'Receive Result Appeal from Prefecture', 'Payment', 'Payment', 'Payment', 'Receive Result Appeal from Prefecture', 'Payment', 'Receive Result Appeal from Prefecture', 'Add penalty', 'Payment', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Payment', 'Payment', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Receive Result Appeal from Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Create Fine', 'Notify Result Appeal to Offender', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Send Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Send for Credit Collection', 'Receive Result Appeal from Prefecture', 'Send Appeal to Prefecture', 'Payment', 'Payment', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Add penalty', 'Payment', 'Payment', 'Payment', 'Send Appeal to Prefecture', 'Receive Result Appeal from Prefecture', 'Payment', 'Payment', 'Receive Result Appeal from Prefecture', 'Payment', 'Receive Result Appeal from Prefecture', 'Payment', 'Payment', 'Send Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Appeal to Judge', 'Receive Result Appeal from Prefecture', 'Send Fine', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Create Fine', 'Create Fine', 'Add penalty', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Insert Date Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Payment', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Create Fine', 'Notify Result Appeal to Offender', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Receive Result Appeal from Prefecture', 'Payment', 'Receive Result Appeal from Prefecture', 'Send Appeal to Prefecture', 'Receiv ...
# ['Payment', 'Notify Result Appeal to Offender', 'Send Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Add penalty', 'Payment', 'Receive Result Appeal from Prefecture', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Payment', 'Send Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Insert Fine Notification', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Payment', 'Payment', 'Payment', 'Notify Result Appeal to Offender', 'Insert Date Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Payment', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Payment', 'Payment', 'Add penalty', 'Receive Result Appeal from Prefecture', 'Insert Date Appeal to Prefecture', 'Add penalty', 'Receive Result Appeal from Prefecture', 'Add penalty', 'Notify Result Appeal to Offender', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Send for Credit Collection', 'Send Appeal to Prefecture', 'Send Fine', 'Send Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Receive Result Appeal from Prefecture', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Payment', 'Appeal to Judge', 'Notify Result Appeal to Offender', 'Send Appeal to Prefecture', 'Payment', 'Send Appeal to Prefecture', 'Payment', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Appeal to Judge', 'Payment', 'Notify Result Appeal to Offender', 'Appeal to Judge', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Send Appeal to Prefecture', 'Send Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Add penalty', 'Send Fine', 'Notify Result Appeal to Offender', 'Send for Credit Collection', 'Send Appeal to Prefecture', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Payment', 'Payment', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Add penalty', 'Add penalty', 'Insert Date Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Payment', 'Create Fine', 'Payment', 'Send Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Send Fine', 'Send Fine', 'Payment', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Appeal to Judge', 'Payment', 'Notify Result Appeal to Offender', 'Receive Result Appeal from Prefecture', 'Appeal to Judge', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Payment', 'Receive Result Appeal from Prefecture', 'Appeal to Judge', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Send Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Insert Date Appeal to Prefecture', 'Add penalty', 'Appeal to Judge', 'Insert Date Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Receive Result Appeal from Prefecture', 'Add penalty', 'Insert Date Appeal to Prefecture', 'Receive Result Appeal from Prefecture', 'Send Appeal to Prefecture', 'Send Fine', 'Add penalty', 'Payment', 'Send Fine', 'Send Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Insert Date A ...
# ['Notify Result Appeal to Offender', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Payment', 'Send for Credit Collection', 'Payment', 'Payment', 'Create Fine', 'Payment', 'Payment', 'Payment', 'Receive Result Appeal from Prefecture', 'Insert Fine Notification', 'Send Appeal to Prefecture', 'Send for Credit Collection', 'Insert Fine Notification', 'Send for Credit Collection', 'Send for Credit Collection', 'Payment', 'Payment', 'Add penalty', 'Notify Result Appeal to Offender', 'Appeal to Judge', 'Payment', 'Payment', 'Send Appeal to Prefecture', 'Payment', 'Send for Credit Collection', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Payment', 'Receive Result Appeal from Prefecture', 'Payment', 'Send for Credit Collection', 'Appeal to Judge', 'Payment', 'Send Appeal to Prefecture', 'Add penalty', 'Payment', 'Send Appeal to Prefecture', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Create Fine', 'Insert Date Appeal to Prefecture', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Insert Date Appeal to Prefecture', 'Receive Result Appeal from Prefecture', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Payment', 'Notify Result Appeal to Offender', 'Payment', 'Receive Result Appeal from Prefecture', 'Notify Result Appeal to Offender', 'Payment', 'Insert Date Appeal to Prefecture', 'Receive Result Appeal from Prefecture', 'Insert Date Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Payment', 'Payment', 'Receive Result Appeal from Prefecture', 'Send Appeal to Prefecture', 'Insert Date Appeal to Prefecture', 'Notify Result Appeal to Offender', 'Notify Result Appeal to Offender', 'Send for Credit Collection', 'Payment', 'Send for Credit Collection', 'Send Appeal to Prefecture', 'Payment', 'Payment', 'Payment', 'Payment']
# ['Payment', 'Payment', 'Payment', 'Payment', 'Appeal to Judge', 'Payment', 'Send for Credit Collection', 'Payment', 'Payment', 'Send Appeal to Prefecture', 'Add penalty', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment']
# ['Payment', 'Payment', 'Add penalty', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment', 'Payment']
# ['Payment', 'Payment', 'Payment', 'Payment']
# ['Payment', 'Payment', 'Payment']
# ['Payment', 'Payment', 'Send for Credit Collection']
# ['Payment', 'Payment']
# ['Payment']
# ['Payment']
# ['Payment']
# ['Payment']
# ['Payment']

# %% [markdown]
# # Decision Tree Prediction

# %%
cases = list(data_train['event concept:name'].unique())  # list of all unique event names
le = preprocessing.LabelEncoder()
le.fit(cases)  # encoding all event names into integers
# Out:
# LabelEncoder()

# %%
def decision_tree(event, pos):

    x_train= le.transform(pos_events[pos]).reshape(-1, 1)
    y_train= le.transform(pos_events[pos+1]).reshape(-1, 1)

    x_test= le.transform(pos_events_test[pos]).reshape(-1, 1)
    y_test= le.transform(pos_events_test[pos+1]).reshape(-1, 1)
    
    classifier = DecisionTreeClassifier()
    classifier.fit(x_train, y_train)
    
    prediction = classifier.predict(event)
    return str(le.inverse_transform(prediction))  # changing the predicted integer back to event name

# %%
test = [['Create Fine']]
test= le.transform(test).reshape(-1, 1)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
decision_tree(test, 0)
# Out:
# "['Send Fine']"
